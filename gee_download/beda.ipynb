# %%
import pandas as pd 
from UtilsFunc import dirlistfiles,filterlist,files_filter_list
import os 
import pandas as pd
from concurrent.futures import ProcessPoolExecutor

pathdir = 'patch256x256'
outtiles_dir = '/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/'
tilenames = os.listdir(outtiles_dir)
tilenames[0]
# Out:
# 'N09_E105'

# %%
def correct_filenaming(fi):
    fo = fi.replace('..tif','.tif')
    os.rename(fi, fo)
    #if not os.path.exist(fo):
        

from glob import glob

# %%
if __name__ == '__main__':
    with ProcessPoolExecutor(50) as PPE:
        for i in range(len(tilenames)):
            if i > 0: break

            tile_patches_path = os.path.join(outtiles_dir,tilenames[i],pathdir)
            print(tile_patches_path)
            fs = glob(f'{tile_patches_path}/*/*.tif')
            print(len(fs))
            #dirlistfiles(tile_patches_path, 'tif', True)
            for fi in fs: PPE.submit(correct_filenaming, fi)
# Out:
# /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/patch256x256
# 97200

# %%
fs = glob(f'{tile_patches_path}/*/*.tif')

zdif_files = files_filter_list(fs, 'zdif')
lidar_files = files_filter_list(fs, 'LiDAR_MekongDelta_EGM08')

txd_files = files_filter_list(fs, 'TDX_DEM_EGM08')
cop_files = files_filter_list(fs, 'COP_DEM')
merit_files = files_filter_list(fs, 'MERIT_EGM08')
nasa_files = files_filter_list(fs, 'NASA_H_EGM08')
aw3d_files = files_filter_list(fs, 'AW3D_H_EGM08')

egm96_files = files_filter_list(fs, 'emg96')
s1_files = files_filter_list(fs, 'S1')
s2_files = files_filter_list(fs, 'S2')
aspect_files = files_filter_list(fs, 'ASPECT')
slope_files = files_filter_list(fs, 'SLOPE') 
roughness_files = files_filter_list(fs, 'roughness') 
tpi_files = files_filter_list(fs, 'TPI')
tri_files = files_filter_list(fs, 'TRI')

copwbm_files = files_filter_list(fs, 'COP_WBM')
ethm_files = files_filter_list(fs, 'ETHm')
eths_files = files_filter_list(fs, 'ETHs')
fnf_files = files_filter_list(fs, 'TDX_FNF')
esawc_files = files_filter_list(fs, 'WC')

barea_files = files_filter_list(fs, 'BuildingArea')
bfraction_files = files_filter_list(fs, 'BuildingFraction')
bheight_files = files_filter_list(fs, 'BuildingHeight')
bvolume_files = files_filter_list(fs, 'BuildingVolume')
wsf_files = files_filter_list(fs, 'WSF') # fix the naming 
wsf_files = [i for i in wsf_files if 'WSF3D' not in i]; print(len(wsf_files))
# Out:
# 1296
# 1296
# 1296
# 1296
# 1296
# 1296
# 1296
# 1296
# 1296
# 1296
# 1296
# 1296
# 1296
# 1296
# 1296
# 1296
# 1296
# 1296
# 1296
# 1296
# 1296
# 1296
# 1296
# 1296
# 6480
# 1296

# %%
ds = {}

ds['zdif'] = zdif_files
ds['lidar'] = lidar_files
ds['tdemx'] = txd_files
ds['cop'] = cop_files
ds['nasa'] = nasa_files
ds['aw3d']= aw3d_files
ds['egm96'] = egm96_files
ds['s1'] = s1_files
ds['s2'] = s2_files
ds['aspect'] = aspect_files
ds['slope'] = slope_files
ds['roughx'] = roughness_files
ds['tpi'] = tpi_files
ds['tri'] = tri_files
ds['copwbm'] = copwbm_files
ds['ethm'] = ethm_files
ds['eths'] = eths_files
ds['fnf'] = fnf_files
ds['wcover']= esawc_files
ds['barea'] = barea_files
ds['bfraction'] = bfraction_files
ds['bheight'] = bheight_files
ds['bvolume'] = bvolume_files
ds['wsf'] = wsf_files

# %%
df = pd.DataFrame(ds)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1296 entries, 0 to 1295
# Data columns (total 24 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   zdif       1296 non-null   object
#  1   lidar      1296 non-null   object
#  2   tdemx      1296 non-null   object
#  3   cop        1296 non-null   object
#  4   nasa       1296 non-null   object
#  5   aw3d       1296 non-null   object
#  6   egm96      1296 non-null   object
#  7   s1         1296 non-null   object
#  8   s2         1296 non-null   object
#  9   aspect     1296 non-null   object
#  10  slope      1296 non-null   object
#  11  roughx     1296 non-null   object
#  12  tpi        1296 non-null   object
#  13  tri        1296 non-null   object
#  14  copwbm     1296 non-null   object
#  15  ethm       1296 non-null   object
#  16  eths       1296 non-null   object
#  17  fnf        1296 non-null   object
#  18  wcover     1296 non-null   object
#  19  barea      1296 non-null   object
#  20  bfraction  1296 non-null   object
#  21  bheight    1296 non-null   object
#  22  bvolume    1296 non-null   object
#  23  wsf        1296 non-null   object
# dtypes: object(24)
# memory usage: 243.1+ KB

# %%
df
# Out:
#                                                    zdif  \
# 0     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 2     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 3     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 4     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# ...                                                 ...
# 1291  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1292  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1293  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1294  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1295  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
#
#                                                   lidar  \
# 0     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 2     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 3     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 4     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# ...                                                 ...
# 1291  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1292  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1293  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1294  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1295  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
#
#                                                   tdemx  \
# 0     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 2     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 3     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 4     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# ...                                                 ...
# 1291  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1292  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1293  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1294  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1295  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
#
#                                                     cop  \
# 0     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 2     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 3     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 4     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# ...                                                 ...
# 1291  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1292  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1293  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1294  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1295  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
#
#                                                    nasa  \
# 0     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 2     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 3     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 4     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# ...                                                 ...
# 1291  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1292  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1293  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1294  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1295  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
#
#                                                    aw3d  \
# 0     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 2     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 3     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 4     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# ...                                                 ...
# 1291  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1292  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1293  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1294  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1295  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
#
#                                                   egm96  \
# 0     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 2     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 3     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 4     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# ...                                                 ...
# 1291  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1292  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1293  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1294  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1295  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
#
#                                                      s1  \
# 0     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 2     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 3     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 4     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# ...                                                 ...
# 1291  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1292  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1293  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1294  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1295  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
#
#                                                      s2  \
# 0     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 2     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 3     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 4     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# ...                                                 ...
# 1291  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1292  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1293  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1294  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1295  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
#
#                                                  aspect  ...  \
# 0     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...  ...
# 1     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...  ...
# 2     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...  ...
# 3     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...  ...
# 4     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...  ...
# ...                                                 ...  ...
# 1291  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...  ...
# 1292  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...  ...
# 1293  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...  ...
# 1294  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...  ...
# 1295  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...  ...
#
#                                                  copwbm  \
# 0     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 2     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 3     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 4     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# ...                                                 ...
# 1291  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1292  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1293  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1294  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1295  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
#
#                                                    ethm  \
# 0     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 2     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 3     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 4     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# ...                                                 ...
# 1291  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1292  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1293  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1294  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1295  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
#
#                                                    eths  \
# 0     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 2     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 3     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 4     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# ...                                                 ...
# 1291  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1292  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1293  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1294  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1295  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
#
#                                                     fnf  \
# 0     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 2     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 3     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 4     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# ...                                                 ...
# 1291  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1292  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1293  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1294  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1295  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
#
#                                                  wcover  \
# 0     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 2     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 3     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 4     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# ...                                                 ...
# 1291  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1292  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1293  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1294  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1295  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
#
#                                                   barea  \
# 0     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 2     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 3     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 4     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# ...                                                 ...
# 1291  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1292  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1293  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1294  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1295  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
#
#                                               bfraction  \
# 0     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 2     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 3     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 4     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# ...                                                 ...
# 1291  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1292  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1293  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1294  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1295  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
#
#                                                 bheight  \
# 0     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 2     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 3     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 4     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# ...                                                 ...
# 1291  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1292  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1293  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1294  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1295  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
#
#                                                 bvolume  \
# 0     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 2     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 3     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 4     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# ...                                                 ...
# 1291  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1292  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1293  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1294  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1295  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
#
#                                                     wsf
# 0     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 2     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 3     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 4     /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# ...                                                 ...
# 1291  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1292  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1293  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1294  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
# 1295  /media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x...
#
# [1296 rows x 24 columns]

# %%
csv_tile_patches_path = os.path.join(tile_patches_path, f'{tilenames[i]}_patches_paths.csv')
df.to_csv(csv_tile_patches_path, index=False)

# %%
namefiles = ['zdif','lidar','tdx',
            'cop','merit','nasa',
            'aw3d','egm96','s1',
            's2','aspect','slope',
            'roughx', 'tpi','tri',
            'copwbm','ethm','eths',
            'fnf', 'wcover','barea',
            'bfraction','bheight'
            'bvolume', 'wsf']
print(len(namefiles))
# Out:
# 24

# %%
df = pd.DataFrame(list(zip(zdif_files,lidar_files,txd_files,
                            cop_files,merit_files,nasa_files,
                            aw3d_files,egm96_files,s1_files,
                            s2_files,aspect_files,slope_files,
                            roughness_files, tpi_files,tri_files,
                            copwbm,ethm_files,eths_files,
                            fnf_files,esawc_files,barea_files,
                            bfraction_files,bheight_files,
                            bvolume_files,wsf_files)),
                    columns=namefiles)
        

        
csv_tile_patches_path = os.path.join(tile_patches_path, f'{tilenames[i]}_patches_paths.csv')
df.to_csv(csv_tile_patches_path, index=False)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# File ~/miniconda3/envs/automl/lib/python3.8/site-packages/pandas/core/internals/construction.py:969, in _finalize_columns_and_data(content, columns, dtype)
#     968 try:
# --> 969     columns = _validate_or_indexify_columns(contents, columns)
#     970 except AssertionError as err:
#     971     # GH#26429 do not raise user-facing AssertionError
#
# File ~/miniconda3/envs/automl/lib/python3.8/site-packages/pandas/core/internals/construction.py:1017, in _validate_or_indexify_columns(content, columns)
#    1015 if not is_mi_list and len(columns) != len(content):  # pragma: no cover
#    1016     # caller's responsibility to check for this...
# -> 1017     raise AssertionError(
#    1018         f"{len(columns)} columns passed, passed data had "
#    1019         f"{len(content)} columns"
#    1020     )
#    1021 elif is_mi_list:
#    1022
#    1023     # check if nested list column, length of each sub-list should be equal
#
# AssertionError: 24 columns passed, passed data had 25 columns
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 df = pd.DataFrame(list(zip(zdif_files,lidar_files,txd_files,
#       2                             cop_files,merit_files,nasa_files,
#       3                             aw3d_files,egm96_files,s1_files,
#       4                             s2_files,aspect_files,slope_files,
#       5                             roughness_files, tpi_files,tri_files,
#       6                             copwbm,ethm_files,eths_files,
#       7                             fnf_files,esawc_files,barea_files,
#       8                             bfraction_files,bheight_files,
#       9                             bvolume_files,wsf_files)),
#      10                     columns=namefiles)
#      14 csv_tile_patches_path = os.path.join(tile_patches_path, f'{tilenames[i]}_patches_paths.csv')
#      15 df.to_csv(csv_tile_patches_path, index=False)
#
# File ~/miniconda3/envs/automl/lib/python3.8/site-packages/pandas/core/frame.py:746, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     744     if columns is not None:
#     745         columns = ensure_index(columns)
# --> 746     arrays, columns, index = nested_data_to_arrays(
#     747         # error: Argument 3 to "nested_data_to_arrays" has incompatible
#     748         # type "Optional[Collection[Any]]"; expected "Optional[Index]"
#     749         data,
#     750         columns,
#     751         index,  # type: ignore[arg-type]
#     752         dtype,
#     753     )
#     754     mgr = arrays_to_mgr(
#     755         arrays,
#     756         columns,
#    (...)
#     759         typ=manager,
#     760     )
#     761 else:
#
# File ~/miniconda3/envs/automl/lib/python3.8/site-packages/pandas/core/internals/construction.py:510, in nested_data_to_arrays(data, columns, index, dtype)
#     507 if is_named_tuple(data[0]) and columns is None:
#     508     columns = ensure_index(data[0]._fields)
# --> 510 arrays, columns = to_arrays(data, columns, dtype=dtype)
#     511 columns = ensure_index(columns)
#     513 if index is None:
#
# File ~/miniconda3/envs/automl/lib/python3.8/site-packages/pandas/core/internals/construction.py:875, in to_arrays(data, columns, dtype)
#     872     data = [tuple(x) for x in data]
#     873     arr = _list_to_arrays(data)
# --> 875 content, columns = _finalize_columns_and_data(arr, columns, dtype)
#     876 return content, columns
#
# File ~/miniconda3/envs/automl/lib/python3.8/site-packages/pandas/core/internals/construction.py:972, in _finalize_columns_and_data(content, columns, dtype)
#     969     columns = _validate_or_indexify_columns(contents, columns)
#     970 except AssertionError as err:
#     971     # GH#26429 do not raise user-facing AssertionError
# --> 972     raise ValueError(err) from err
#     974 if len(contents) and contents[0].dtype == np.object_:
#     975     contents = _convert_object_array(contents, dtype=dtype)
#
# ValueError: 24 columns passed, passed data had 25 columns

# %%
path = '/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N10_E105/MekongDelta_N10_E105.csv'

df = pd.read_csv(path)

# %% [markdown]
# ['lgeoid',
#  'egm08',
#  'egm96',
#  'lidar',
#  'tdemx',
#  'nasa',
#  'aw3dh',
#  'aw3dH',
#  'cop',
#  'merit',
#  'S1',
#  'S2',
#  'ethm',
#  'eths',
#  'wsf',
#  'esawc',
#  'copwbm',
#  'tdxcom',
#  'tdxcov',
#  'tdxwam',
#  'tdxfnf',
#  'tdemx_egm08',
#  'lidar_egm08',
#  'nasa_egm08',
#  'aw3d_egm08',
#  'merit_egm08',
#  'zdif',
#  'slope',
#  'aspect',
#  'tpi',
#  'tri',
#  'roughness',
#  'bheight',
#  'barea',
#  'bfraction',
#  'bvolume']

# %%
#df.name.tolist()
