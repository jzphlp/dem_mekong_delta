# %%
from glob import glob
import os 
from geotile import GeoTile
from UtilsTiling import geotile_generate_tiles
from concurrent.futures import ProcessPoolExecutor
wdir = '/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/'
patch_size = 256
cpus = 100
# move this locally for faster readings
# change nameing convetion for Lgeoid and anyother tht needs changing
# uw the code and merge with  from GeoPatch import TrainPatch >>> Tuesday after presentation

# %%
if __name__ == '__main__':
    with ProcessPoolExecutor(cpus) as PEX:
        tilenames = os.listdir(wdir)
        for i in range(len(tilenames)):
            if i >= 1: break
            itile = tilenames[i]
            tile_path = os.path.join(wdir, itile)
            fs_tile = sorted(glob(f'{tile_path}/*.tif'))
            tile_patch_dir = os.path.join(tile_path, f'patch{patch_size}x{patch_size}')
            os.makedirs(tile_patch_dir, exist_ok=True)
            #print(tile_path)
            for tif_path in fs_tile:
                varname = itile + '_'+os.path.basename(tif_path).replace(itile, '')[1:].replace('.tif', '') #.lower()
                var_tile_patch_dir = os.path.join(tile_patch_dir, varname)
                os.makedirs(var_tile_patch_dir, exist_ok=True)
                gpkg_path = tif_path.replace('.tif', '.gpkg')
                print(f'file:{tif_path} \ndir:{var_tile_patch_dir} \ngpkg:{gpkg_path}')
                PEX.submit(geotile_generate_tiles, tif_path,gpkg_path,var_tile_patch_dir)

        #geotile_generate_tiles(tif_path, gpkg_path, dir_path)
        #print(bnane)
# Out:
# file:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_AW3D_H.tif
# dir:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/patch256x256/N09_E105_AW3D_H
# gpkg:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_AW3D_H.gpkg
# file:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_AW3D_H_EGM08.tif
# dir:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/patch256x256/N09_E105_AW3D_H_EGM08
# gpkg:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_AW3D_H_EGM08.gpkg
# file:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_AW3D_h.tif
# dir:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/patch256x256/N09_E105_AW3D_h
# gpkg:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_AW3D_h.gpkg
# file:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_COP_DEM.tif
# dir:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/patch256x256/N09_E105_COP_DEM
# gpkg:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_COP_DEM.gpkg
# file:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_COP_WBM.tif
# dir:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/patch256x256/N09_E105_COP_WBM
# gpkg:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_COP_WBM.gpkg
# file:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_ETHm.tif
# dir:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/patch256x256/N09_E105_ETHm
# gpkg:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_ETHm.gpkg
# file:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_ETHs.tif
# dir:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/patch256x256/N09_E105_ETHs
# gpkg:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_ETHs.gpkg
# file:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_Lgeoid_GEOID_FFT_20190703_Vietnam.tif
# dir:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/patch256x256/N09_E105_Lgeoid_GEOID_FFT_20190703_Vietnam
# gpkg:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_Lgeoid_GEOID_FFT_20190703_Vietnam.gpkg
# file:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_LiDAR_MekongDelta.tif
# dir:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/patch256x256/N09_E105_LiDAR_MekongDelta
# gpkg:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_LiDAR_MekongDelta.gpkg
# file:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_LiDAR_MekongDelta_EGM08.tif
# dir:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/patch256x256/N09_E105_LiDAR_MekongDelta_EGM08
# gpkg:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_LiDAR_MekongDelta_EGM08.gpkg
# file:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_MERIT.tif
# dir:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/patch256x256/N09_E105_MERIT
# gpkg:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_MERIT.gpkg
# file:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_MERIT_EGM08.tif
# dir:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/patch256x256/N09_E105_MERIT_EGM08
# gpkg:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_MERIT_EGM08.gpkg
# file:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_NASA_H.tif
# dir:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/patch256x256/N09_E105_NASA_H
# gpkg:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_NASA_H.gpkg
# file:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_NASA_H_EGM08.tif
# dir:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/patch256x256/N09_E105_NASA_H_EGM08
# gpkg:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_NASA_H_EGM08.gpkg
# file:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_S1.tif
# dir:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/patch256x256/N09_E105_S1
# gpkg:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_S1.gpkg
# file:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_S2.tif
# dir:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/patch256x256/N09_E105_S2
# gpkg:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_S2.gpkg
# file:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_TDX_COM.tif
# dir:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/patch256x256/N09_E105_TDX_COM
# gpkg:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_TDX_COM.gpkg
# file:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_TDX_COV.tif
# dir:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/patch256x256/N09_E105_TDX_COV
# gpkg:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_TDX_COV.gpkg
# file:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_TDX_DEM.tif
# dir:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/patch256x256/N09_E105_TDX_DEM
# gpkg:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_TDX_DEM.gpkg
# file:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_TDX_DEM_EGM08.tif
# dir:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/patch256x256/N09_E105_TDX_DEM_EGM08
# gpkg:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_TDX_DEM_EGM08.gpkg
# file:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_TDX_DEM_erode.tif
# dir:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/patch256x256/N09_E105_TDX_DEM_erode
# gpkg:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_TDX_DEM_erode.gpkg
# file:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_TDX_DEM_masked.tif
# dir:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/patch256x256/N09_E105_TDX_DEM_masked
# gpkg:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_TDX_DEM_masked.gpkg
# file:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_TDX_FNF.tif
# dir:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/patch256x256/N09_E105_TDX_FNF
# gpkg:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_TDX_FNF.gpkg
# file:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_TDX_WAM.tif
# dir:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/patch256x256/N09_E105_TDX_WAM
# gpkg:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_TDX_WAM.gpkg
# file:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_WC.tif
# dir:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/patch256x256/N09_E105_WC
# gpkg:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_WC.gpkg
# file:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_WSF.tif
# dir:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/patch256x256/N09_E105_WSF
# gpkg:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_WSF.gpkg
# file:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_emg08.tif
# dir:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/patch256x256/N09_E105_emg08
# gpkg:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_emg08.gpkg
# file:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_emg96.tif
# dir:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/patch256x256/N09_E105_emg96
# gpkg:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_emg96.gpkg
# file:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_zdif.tif
# dir:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/patch256x256/N09_E105_zdif
# gpkg:/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_zdif.gpkg
# Creating new index file...
# Creating new index file...
# Creating new index file...
# Creating new index file...
# Creating new index file...
# Creating new index file...
# Creating new index file...
# Creating new index file...
# Creating new index file...
# Creating new index file...
# Creating new index file...
# Creating new index file...
# Creating new index file...
# Creating new index file...
# Creating new index file...
# Creating new index file...
# Creating new index file...
# Creating new index file...
# Creating new index file...
# Creating new index file...
# Creating new index file...
# Creating new index file...
# Creating new index file...
# Creating new index file...
# Creating new index file...
# Creating new index file...
# Creating new index file...
# Creating new index file...
# Creating new index file...

# %%
fs_tile
# Out:
# ['/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_AW3D_H.tif',
#  '/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_AW3D_H_EGM08.tif',
#  '/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_AW3D_h.tif',
#  '/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_COP_DEM.tif',
#  '/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_COP_WBM.tif',
#  '/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_ETHm.tif',
#  '/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_ETHs.tif',
#  '/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_Lgeoid_GEOID_FFT_20190703_Vietnam.tif',
#  '/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_LiDAR_MekongDelta.tif',
#  '/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_LiDAR_MekongDelta_EGM08.tif',
#  '/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_MERIT.tif',
#  '/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_MERIT_EGM08.tif',
#  '/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_NASA_H.tif',
#  '/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_NASA_H_EGM08.tif',
#  '/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_S1.tif',
#  '/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_S2.tif',
#  '/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_TDX_COM.tif',
#  '/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_TDX_COV.tif',
#  '/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_TDX_DEM.tif',
#  '/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_TDX_DEM_EGM08.tif',
#  '/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_TDX_DEM_erode.tif',
#  '/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_TDX_DEM_masked.tif',
#  '/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_TDX_FNF.tif',
#  '/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_TDX_WAM.tif',
#  '/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_WC.tif',
#  '/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_WSF.tif',
#  '/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_emg08.tif',
#  '/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_emg96.tif',
#  '/media/ljp238/6tb/Joseph/DATASETS/OUT_TILES/1x1degree/N09_E105/N09_E105_zdif.tif']
